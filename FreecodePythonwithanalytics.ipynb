# %% [markdown]
# <a href="https://colab.research.google.com/github/AdityaWarrior94/Full-Stack-Data-Science-Pro/blob/main/FreecodePythonwithanalytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas lxml html5lib

# %%
import pandas as pd

# URL of the HTML page containing the table
html_url = "https://www.basketball-reference.com/leagues/NBA_2019_per_game.html"

# Read all tables from the URL
nba_tables = pd.read_html(html_url)

# Display the first table
nba_stats = nba_tables[0]
print(nba_stats.head())
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB  DRB  \
# 0  1  Álex Abrines  SG  25  OKC  31   2  19.0  1.8   5.1  ...  .923  0.2  1.4
# 1  2    Quincy Acy  PF  28  PHO  10   0  12.3  0.4   1.8  ...  .700  0.3  2.2
# 2  3  Jaylen Adams  PG  22  ATL  34   1  12.6  1.1   3.2  ...  .778  0.3  1.4
# 3  4  Steven Adams   C  25  OKC  80  80  33.4  6.0  10.1  ...  .500  4.9  4.6
# 4  5   Bam Adebayo   C  21  MIA  82  28  23.3  3.4   5.9  ...  .735  2.0  5.3
#
#    TRB  AST  STL  BLK  TOV   PF   PTS
# 0  1.5  0.6  0.5  0.2  0.5  1.7   5.3
# 1  2.5  0.8  0.1  0.4  0.4  2.4   1.7
# 2  1.8  1.9  0.4  0.1  0.8  1.3   3.2
# 3  9.5  1.6  1.5  1.0  1.7  2.6  13.9
# 4  7.3  2.2  0.9  0.8  1.5  2.5   8.9
#
# [5 rows x 30 columns]

# %%
nba=nba_tables[0]

# %%
nba.head()
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB  DRB  \
# 0  1  Álex Abrines  SG  25  OKC  31   2  19.0  1.8   5.1  ...  .923  0.2  1.4
# 1  2    Quincy Acy  PF  28  PHO  10   0  12.3  0.4   1.8  ...  .700  0.3  2.2
# 2  3  Jaylen Adams  PG  22  ATL  34   1  12.6  1.1   3.2  ...  .778  0.3  1.4
# 3  4  Steven Adams   C  25  OKC  80  80  33.4  6.0  10.1  ...  .500  4.9  4.6
# 4  5   Bam Adebayo   C  21  MIA  82  28  23.3  3.4   5.9  ...  .735  2.0  5.3
#
#    TRB  AST  STL  BLK  TOV   PF   PTS
# 0  1.5  0.6  0.5  0.2  0.5  1.7   5.3
# 1  2.5  0.8  0.1  0.4  0.4  2.4   1.7
# 2  1.8  1.9  0.4  0.1  0.8  1.3   3.2
# 3  9.5  1.6  1.5  1.0  1.7  2.6  13.9
# 4  7.3  2.2  0.9  0.8  1.5  2.5   8.9
#
# [5 rows x 30 columns]

# %%
import requests
html_url = "https://en.wikipedia.org/wiki/Indian_Premier_League"
r = requests.get(html_url)

# %%
wiki_tables=pd.read_html(r.text,header=0)

# %%
len(wiki_tables)
# Out:
# 34

# %%
ipl=wiki_tables[15]

# %%
ipl.head()
# Out:
#    Sponsor            Period Estimated annual sponsorship fee
# 0      DLF         2008–2012       ₹40 crore (US$4.8 million)
# 1    Pepsi         2013–2015     ₹79.2 crore (US$9.5 million)
# 2     Vivo        2016, 2017     ₹100 crore (US$12.0 million)
# 3     Vivo  2018, 2019, 2021     ₹440 crore (US$52.7 million)
# 4  Dream11              2020     ₹222 crore (US$26.6 million)
